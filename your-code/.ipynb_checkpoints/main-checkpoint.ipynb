# %% [markdown]
# # Survival Analysis Lab
#
# Complete the following exercises to solidify your knowledge of survival analysis.

# %%
# !pip install chart-studio
# Out:
# ...
#      |████████████████████████████████| 64 kB 207 kB/s eta 0:00:01
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11448 sha256=5f1283d25fd9d10bd0728f6631fb6d925a4aeb4419ab1b66208c2a3a678eeb07
#   Stored in directory: /Users/marcosrubio/Library/Caches/pip/wheels/ce/18/7f/e9527e3e66db1456194ac7f61eb3211068c409edceecff2d31
# Successfully built retrying
# ...

# %%
! pip install lifelines
# Out:
# ...
#      |████████████████████████████████| 349 kB 1.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 68 kB 1.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 48 kB 697 kB/s eta 0:00:01
# ...
#   Created wheel for autograd-gamma: filename=autograd_gamma-0.5.0-py3-none-any.whl size=4049 sha256=2a62f81f0dfadb0c84561b2d38e6ec6df1c6d41f14e77701c50367e89629d3b8
#   Stored in directory: /Users/marcosrubio/Library/Caches/pip/wheels/a8/03/64/8557323821d25118c3a2dc1646996f7a962a8970d4b7d22473
# Successfully built autograd-gamma
# ...

# %%
# !conda update -n base -c defaults conda -y
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/marcosrubio/opt/anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.13.0               |   py39hecd8cb5_0         906 KB
#     conda-package-handling-1.8.1|   py39hca72f7f_0         1.5 MB
#     conda-repo-cli-1.0.5       |   py39hecd8cb5_0         106 KB
#     pathlib-1.0.1              |     pyhd3eb1b0_1          17 KB
#     pyjwt-2.4.0                |   py39hecd8cb5_0          35 KB
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   pathlib            pkgs/main/noarch::pathlib-1.0.1-pyhd3eb1b0_1
#
# The following packages will be UPDATED:
#
# ...

# %%
# !conda install -c conda-forge cufflinks-py -y
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/marcosrubio/opt/anaconda3
#
#   added / updated specs:
#     - cufflinks-py
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     chart-studio-1.1.0         |     pyh9f0ad1d_0          51 KB  conda-forge
#     colorlover-0.3.0           |             py_0          12 KB  conda-forge
#     conda-4.13.0               |   py39h6e9494a_1         986 KB  conda-forge
#     cufflinks-py-0.17.3        |             py_0           4 KB  conda-forge
#     plotly-5.9.0               |     pyhd8ed1ab_0         7.0 MB  conda-forge
#     python-cufflinks-0.17.3    |             py_0          59 KB  conda-forge
#     python_abi-3.9             |           2_cp39           4 KB  conda-forge
#     retrying-1.3.3             |             py_2          11 KB  conda-forge
# ...

# %%
import pandas as pd
import chart_studio.plotly as py
import cufflinks as cf
from lifelines import KaplanMeierFitter

import plotly.express as px

import numpy as np

cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data = pd.read_csv('../data/attrition.csv')

# %%
data.head(3).T
# Out:
#                                         0                       1  \
# Age                                    41                      49
# Attrition                               1                       0
# BusinessTravel              Travel_Rarely       Travel_Frequently
# DailyRate                            1102                     279
# Department                          Sales  Research & Development
# DistanceFromHome                        1                       8
# Education                               2                       1
# EducationField              Life Sciences           Life Sciences
# EmployeeCount                           1                       1
# EmployeeNumber                          1                       2
# EnvironmentSatisfaction                 2                       3
# Gender                             Female                    Male
# HourlyRate                             94                      61
# ...

# %% [markdown]
# ## 1. Generate and plot a survival function that shows how employee retention rates vary by gender and employee age.
#
# *Tip: If your lines have gaps in them, you can fill them in by using the `fillna(method=ffill)` and the `fillna(method=bfill)` methods and then taking the average. We have provided you with a revised survival function below that you can use for the exercises in this lab*

# %%
def survival(data, group_field, time_field, event_field):
    kmf = KaplanMeierFitter()
    results = []

    for i in data[group_field].unique():
        group = data[data[group_field]==i]
        T = group[time_field]
        E = group[event_field]
        kmf.fit(T, E, label=str(i))
        results.append(kmf.survival_function_)

    survival = pd.concat(results, axis=1)
    front_fill = survival.fillna(method='ffill')
    back_fill = survival.fillna(method='bfill')
    smoothed = (front_fill + back_fill) / 2
    return smoothed

# %%
gender_age = survival(data, 'Gender', 'Age', 'Attrition')
px.line(data_frame=gender_age, title = 'Retention Rates by Gender over the Years')

# %% [markdown]
# ## 2. Compare the plot above with one that plots employee retention rates by gender over the number of years the employee has been working for the company.

# %%
gender_years = survival(data, 'Gender', 'YearsAtCompany', 'Attrition')
px.line(data_frame=gender_years, title = 'Retention Rates by Gender over the Years Working for the Company')

# %% [markdown]
# ## 3. Let's look at retention rate by gender from a third perspective - the number of years since the employee's last promotion. Generate and plot a survival curve showing this.

# %%
gender_years = survival(data, 'Gender', 'YearsSinceLastPromotion', 'Attrition')
px.line(data_frame=gender_years, title = 'Retention Rates by Gender over the Years since their last promotion')

# %% [markdown]
# ## 4. Let's switch to looking at retention rates from another demographic perspective: marital status. Generate and plot survival curves for the different marital statuses by number of years at the company.

# %%
status_years = survival(data, 'MaritalStatus', 'YearsAtCompany', 'Attrition')
px.line(data_frame = status_years, title = 'Retention Rates by marital status over their total Years at the company')

# %% [markdown]
# ## 5. Let's also look at the marital status curves by employee age. Generate and plot the survival curves showing retention rates by marital status and age.

# %%
status_age = survival(data, 'MaritalStatus', 'Age', 'Attrition')
px.line(data_frame = status_age, title = 'Retention Rates by marital status and age')

# %% [markdown]
# ## 6. Now that we have looked at the retention rates by gender and marital status individually, let's look at them together.
#
# Create a new field in the data set that concatenates marital status and gender, and then generate and plot a survival curve that shows the retention by this new field over the age of the employee.

# %%
data['gender_marital_concat'] = data['Gender']+' - '+data['MaritalStatus']

# %%
concat_age = survival(data, 'gender_marital_concat', 'Age', 'Attrition')
px.line(data_frame = concat_age, title = 'Retention Rates by gender/marital status and age')

# %% [markdown]
# ## 6. Let's find out how job satisfaction affects retention rates. Generate and plot survival curves for each level of job satisfaction by number of years at the company.

# %%
satisfaction_years = survival(data, 'JobSatisfaction', 'YearsAtCompany', 'Attrition')
px.line(data_frame = satisfaction_years, title = 'Retention Rates by satisfaction level over total years at the company')

# %% [markdown]
# ## 7. Let's investigate whether the department the employee works in has an impact on how long they stay with the company. Generate and plot survival curves showing retention by department and years the employee has worked at the company.

# %%
department_years = survival(data, 'Department', 'YearsAtCompany', 'Attrition')
px.line(data_frame = department_years, title = 'Retention Rates by department over total years at the company')

# %% [markdown]
# ## 8. From the previous example, it looks like the sales department has the highest attrition. Let's drill down on this and look at what the survival curves for specific job roles within that department look like.
#
# Filter the data set for just the sales department and then generate and plot survival curves by job role and the number of years at the company.

# %%
data_sales = data[data['Department'] == 'Sales']

# %%
job_years = survival(data_sales, 'JobRole', 'YearsAtCompany', 'Attrition')
px.line(data_frame = job_years, title = 'Retention Rates by job roles within the sales department over total years at the company')

# %% [markdown]
# ## 9. Let examine how compensation affects attrition.
#
# - Use the `pd.qcut` method to bin the HourlyRate field into 5 different pay grade categories (Very Low, Low, Moderate, High, and Very High).
# - Generate and plot survival curves showing employee retention by pay grade and age.

# %%
data['pay_categories'] = pd.qcut(data['HourlyRate'], q = 5, labels = ['Very Low', 'Low', 'Moderate', 'High', 'Very High'])

# %%
categories_age = survival(data, 'pay_categories', 'Age', 'Attrition')
px.line(data_frame = categories_age, title = 'Retention Rates by pay categories over age of the person')

# %% [markdown]
# ## 10. Finally, let's take a look at how the demands of the job impact employee attrition.
#
# - Create a new field whose values are 'Overtime' or 'Regular Hours' depending on whether there is a Yes or a No in the OverTime field.
# - Create a new field that concatenates that field with the BusinessTravel field.
# - Generate and plot survival curves showing employee retention based on these conditions and employee age.

# %%
data['new_overtime'] = np.where(data['OverTime']=='No','Regular Hours','Overtime')

# %%
data['new_travel_concat'] = data['new_overtime']+' - '+data['BusinessTravel']

# %%
demands_job = survival(data, 'new_travel_concat', 'Age', 'Attrition')
px.line(data_frame = demands_job, title = 'Retention Rates by exploited workers over age of the person')
